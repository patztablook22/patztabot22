# %%
import sys  
sys.path.insert(0, '../src/')

from transfos.components import positional_encoding
import matplotlib.pyplot as plt
import numpy as np

# %%
length = 512
model_dim = 256

pe = positional_encoding(length, model_dim)

# %%
plt.matshow(np.concatenate([pe, pe[:,::2], pe[:,1::2]], axis=-1))
plt.xticks([])
plt.xlabel('embedding vector (all, even, odd)')
plt.ylabel('sequence position')
# Out:
# Text(0, 0.5, 'sequence position')
